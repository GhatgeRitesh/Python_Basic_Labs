# %% [markdown]
# # This is Labs for Module2 python for datascience ai and development

# %%
#List and tuples 
"""
are the compound data types in python and most important part of datastructures in python
"""
# Out:
# '\nare the compound data types in python and most important part of datastructures in python\n'

# %%
#tuples 
"""
are an oredered sequence
tuples are written as comma-separated elements within parenthesis ()
all types of data can be stored into single tuple 
but the type of tuple variable is tuple 
tup=("rites",12,12.5)
type(tup)==>tuple
elements are accessed via index 
index may be negative as python supports negative indexing starting from last index -1

can be accessed as tup[0]==>"ritesh"

we can concatate or combine tuples by adding them

tup1=("rock",1)
tup2=tup1+("hard",2)
combineoutput as ==> ("rock",1,"hard",2)

Slicing of tuple

if we want first n elements we use 

tup1[starting index:end index +1] like tup1[0:3]

to obtain the length of tuple we use 
len(tuple)


tuples are immutable 

tuples are objects and may have multiple references 

hence making them immutable 

on using the functions on tuples they return lists 
as tup=()
tupsorted=sorted(tup)

type(tupsorted):list

***** Nesting Complex data type as List<List<Integer>> in java********
it can contain many tuples and can be accessed using index

tup(1,2,("roxck","haed"),(3,4),("disco",(2,1)))
to access roxck we use tup[2][0]:roxck
to access 2 from 4
tup[4][1][0]

"""
tup=(1,2,("roxck","haed"),(3,4),("disco",(2,1)))
print(tup[4][1][0])
# Out:
# 2

# %%
#List
"""
popular DS in python 

ordered sequence 

list is represented by [] brackerts 

lists are mutable in many respects

************** Nesting in list 
it may contain any data types and also tuples 
it is accessed as indexing method same like tuples

**********slicing in list same as tuple
list[3:5]
len(list)==> index+1 same as java tuple etc 

combining and concatinating list is same as the tuples 

lists are mutable as 

list.extend(["pop",10]) arguments are the new list that are concatinated to original list

list.append(["pop",10]) arguments in the append method are considered as single element and are inserted as single element as
list[elements,["pop",10]] 

also elements can be inserted as list[0]="a"
list:["a",elements,["pop",10]]

we can delete the element of list by del(list[0]) arg as element 

we CAN convert string into a list by applying split() function to the string as 
str="hi there ritesh"
str.split():["hi","there","ritesh"]

we can also pass delimiter for split function as split(",")

multiple references referencing to single object is called 'Aliasing' 

lists can be aliased

if element is changed by one reference other refernce is also have changed values it affects on each instance

***cloning list [ duplicating creating new instance of the list object with new instance ]
a=[1,2,4]
b=a[:] =>b has same list as a with new object 

now changes on a are not affected on b

to get more information on the DS or any objects just pass them into help() finction as argument 

to delete the element from the list or any datastructure we use 

del(list[index])
like del(list[0])
"""
a=[1,2,3]
#help(a)
a_s =sorted(a)
a_s
# Out:
# [1, 2, 3]

# %%
a=(1,2,3,4,5)
a[1:4]
# Out:
# (2, 3, 4)

# %% [markdown]
# # Dictionries
# * type of Collections in python

# %%
"""
dictionary has keys and values keys are not usually integers 
keys are alias for indexes 
unlike list dictionaries have keys

to declare dictionary we use  {} brackets 

Keys should be immutable and unique

the values can be immutable , mutable , and duplicates

example 
dic={"keys":"values"} values can be of any type 

each key and value pair is separeted by a comma

to retrive the data from dictionary we use 

dic["key"]:value ==> we get the value 

to add the new value to dictionary we use

dic['key']='vaule' 

we can delete anpair as :
del(dic["pair"])

to validate the presence of element in dictionary we use :

"key" in dic 
==> returns boolean value

to see all the keys in dictionary we use:
dic.keys()==>[....] list like object with all keys 

In same way we can obtain the list of values
dic.values()=>[....] 


methods to create the dictionary 
# Create the dictionary
keys can be anything

Dict = {"key1": 1, "key2": "2", "key3": [3, 3, 3], "key4": (4, 4, 4), ('key5'): 5, (0, 1): 6}
Dict["key5"]
Dict[(0, 1)]=> this is the key 

items()	
Retrieves all key-value pairs as tuples and converts them into a list of tuples. Each tuple consists of a key and its corresponding value.

Syntax:

1
items_list = list(dict_name.items())
Copied!
Example:

1
info = list(person.items())

copy()	
Creates a shallow copy of the dictionary. The new dictionary contains the same key-value pairs as the original, but they remain distinct objects in memory.

Syntax:

1
new_dict = dict_name.copy()
Copied!
Example:

1
2
new_person = person.copy()
new_person = dict(person) # another way to create a copy of dictionary

update()	
The update() method merges the provided dictionary into the existing dictionary, adding or updating key-value pairs.

Syntax:

1
dict_name.update({key: value})
Copied!
Example:

1
person.update({"Profession": "Doctor"})

Defining Sets	A set is an unordered collection of unique elements. Sets are enclosed in curly braces `{}`. They are useful for storing distinct values and performing set operations.	Example:
1
2
empty_set = set() #Creating an Empty 
Set fruits = {"apple", "banana", "orange"}
Copied!
discard()	Use the `discard()` method to remove a specific element from the set. Ignores if the element is not found.	Syntax:
1
set_name.discard(element) 
Copied!
Example:

1
fruits.discard("apple")


pop()	The `pop()` method removes and returns an arbitrary element from the set. It raises a `KeyError` if the set is empty. Use this method to remove elements when the order doesn't matter.	Syntax:
1
removed_element = set_name.pop() 
Copied!
Example:

1
removed_fruit = fruits.pop()
"""

# %% [markdown]
# # Sets
# * set is the type of collection in python

# %%
"""
sets can have multiple type of data into itself

sets do not record element position [it is unordered]

sets only contian unique elements duplicates are not allowed

to declare a set we use {}

a={1,2,3,4,1,3,3}

you can convert the list into set by using set() function by giving list as argument it is called typecasting 

set Operations : similar to vienn diagram 

add new item as : a.add("item")

remove item from set :a.remove("item")

verify element present in sets as : "item" in a => returns boolean 

Mathematical set Operations ***************************************************************************

To find the ****intersection**** of two sets we use a & b here a and b are two different sets 
[In python with sets we use & to find the intersection betweeen two sets ]

the intersection of two sets is new set as :
a3=a1&a2

To find the ****Union**** of two sets we use 
a1.union(a2) => check the result by putting variable or set itself is changed 

To check the subset of two sets 
a1 and a3 are the two sets as:
a3.issubset(a1) => returns boolean 

To find difference use : a1.difference(a2)

To find intersection use :a1.intersection(a2)

To find susbes :a1.issubset(a2)

union:a1.union(a2)

superset:a1.issuperset(a2)


"""
# Out:
# '\nsets can have multiple type of data into itself\n\nsets do not record element position [it is unordered]\n\nsets only contian unique elements duplicates are not allowed\n\nto declare a set we use {}\n\na={1,2,3,4,1,3,3}\n\nyou can convert the list into set by using set() function by giving list as argument it is called typecasting \n\nset Operations : similar to vienn diagram \n\nadd new item as : a.add("item")\n\nremove item from set :a.remove("item")\n\nverify element present in sets as : "item" in a => returns boolean \n\nMathematical set Operations ***************************************************************************\n\nTo find the ****intersection**** of two sets we use a & b here a and b are two different sets \n[In python with sets we use & to find the intersection betweeen two sets ]\n\nthe intersection of two sets is new set as :\na3=a1&a2\n\nTo find the ****Union**** of two sets we use \na1.union(a2) => check the result by putting variable or set itself is changed 
# ...

# %% [markdown]
# # Module 2 Summary: Python Data Structures
# 89
# Congratulations! You have completed this module. At this point, you know that:
# 89
#
# In Python, we often use tuples to group related data together.Tuples refer to ordered and immutable collections of elements89.
#
# Tuples are usually written as comma-separated elements in parentheses “(89)".
#
# You can include strings, integers, and floats in tuples and access them using both positive and negative ind89ices.
#
# You can perform operations such as combining, concatenating, and slicing on 89tuples.
#
# Tuples are immutable, so you need to create a new tuple to manip89u89late it.
#
# Tuples, termed nesting, can include other tuples of complex 89data types.
#
# You can access elements in a nested tuple thro89ugh indexing.
#
# Lists in Python contain ordered collections of items that can hold elements of different types and are mutable, allowing for versatile data storage an89d manipulation.
#
# A list is an ordered sequence, represented with squa89re brackets "[]".
#
# Lists possess mutability, rendering t89hem akin to tuples.
#
# A list can contain strings, integers, and floats; you can 89nest lists within it.
#
# You can access each element in a list using both positive89 and negative indexing.
#
# Concatenating or appending a list will result in the modif89ication of the same list.
#
# You can perform operations such as adding, deleting, splitti89ng, and so forth on a list.
#
# You can separate element89s in a list using delimiters.
#
# Aliasing occurs when multiple names refer to the same object.
#
# You can also clone a list to create another list.
#
# Dictionaries in Python are key-value pairs that provide a flexible way to store and retrieve data based on unique keys.
#
# Dictionaries consist of keys and values, both composed of string elements.
#
# You denote dictionaries using curly brackets.
#
# The keys necessitate immutability and uniqueness.
#
# The values may be either immutable or mutable, and they allow duplicates.
#
# You separate each key-value pair with a comma, and you can use color highlighting to make the key more visible.
#
# You can assign dictionaries to a variable.
#
# You use the key as an argument to retrieve the corresponding value.
#
# You can make additions and deletions to dictionaries.
#
# You can perform an operation on a dictionary to check the key, which results in a true or false output.
#
# You can apply methods to obtain a list of keys and values in a dictionary.
#
# Sets in Python are collections of unique elements, useful for tasks such as removing duplicates and performing set operations like union and intersection. Sets lack order.
#
# Curly brackets "{}" are helpful for defining elements of a set.
#
# Sets do not contain duplicate items.
#
# A list passed through the set function generates a set containing unique elements.
#
# You use “Set Operations” to perform actions such as adding, removing, and verifying elements in a set.
#
# You can combine sets using the ampersand "&" operator to obtain the common elements from both sets.
#
# You can use the Union function to combine two sets, including both the common and unique elements from both sets.
#
# The sub-set method is used to determine if two or more sets are subsets.
